# %%
# example of ordinal encoding for a neural network
from pandas import read_csv
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import OneHotEncoder
from sklearn.preprocessing import OrdinalEncoder
from keras.models import Sequential
from keras.layers import Dense

# load the dataset
def load_dataset(filename):
	# load the dataset as a pandas DataFrame
	data = read_csv(filename, header=None)
	# retrieve numpy array
	dataset = data.values
	# split into input (X) and output (y) variables
	X = dataset[:, :-1]
	y = dataset[:,-1]
	# format all fields as string
	X = X.astype(str)
	# reshape target to be a 2d array
	y = y.reshape((len(y), 1))
	return X, y

# prepare input data
def prepare_inputs(X_train, X_test):
	oe = OneHotEncoder() #OrdinalEncoder()
	oe.fit(X_train)
	X_train_enc = oe.transform(X_train)
	X_test_enc = oe.transform(X_test)
	return X_train_enc, X_test_enc

# prepare target
def prepare_targets(y_train, y_test):
	le = LabelEncoder()
	le.fit(y_train)
	y_train_enc = le.transform(y_train)
	y_test_enc = le.transform(y_test)
	return y_train_enc, y_test_enc

# load the dataset
X, y = load_dataset('breast-cancer.csv')
# split into train and test sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33, random_state=1)
# prepare input data
X_train_enc, X_test_enc = prepare_inputs(X_train, X_test)
# prepare output data
y_train_enc, y_test_enc = prepare_targets(y_train, y_test)
# define the  model
model = Sequential()
model.add(Dense(10, input_dim=X_train_enc.shape[1], activation='relu', kernel_initializer='he_normal'))
model.add(Dense(1, activation='sigmoid'))
# compile the keras model
model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])
# fit the keras model on the dataset
model.fit(X_train_enc, y_train_enc, epochs=100, batch_size=16, verbose=2)
# evaluate the keras model
_, accuracy = model.evaluate(X_test_enc, y_test_enc, verbose=0)
print('Accuracy: %.2f' % (accuracy*100))
# Out:
# Epoch 1/100
# c:\Users\saifu\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\preprocessing\_label.py:99: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# c:\Users\saifu\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\preprocessing\_label.py:134: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, dtype=self.classes_.dtype, warn=True)
# c:\Users\saifu\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\preprocessing\_label.py:134: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, dtype=self.classes_.dtype, warn=True)
# 12/12 - 1s - loss: 0.7747 - accuracy: 0.3194 - 779ms/epoch - 65ms/step
# Epoch 2/100
# 12/12 - 0s - loss: 0.7199 - accuracy: 0.4660 - 30ms/epoch - 3ms/step
# Epoch 3/100
# 12/12 - 0s - loss: 0.6746 - accuracy: 0.5916 - 24ms/epoch - 2ms/step
# Epoch 4/100
# 12/12 - 0s - loss: 0.6442 - accuracy: 0.6754 - 23ms/epoch - 2ms/step
# Epoch 5/100
# 12/12 - 0s - loss: 0.6195 - accuracy: 0.7277 - 26ms/epoch - 2ms/step
# Epoch 6/100
# 12/12 - 0s - loss: 0.6005 - accuracy: 0.7592 - 80ms/epoch - 7ms/step
# Epoch 7/100
# 12/12 - 0s - loss: 0.5861 - accuracy: 0.7539 - 42ms/epoch - 3ms/step
# Epoch 8/100
# 12/12 - 0s - loss: 0.5736 - accuracy: 0.7487 - 40ms/epoch - 3ms/step
# Epoch 9/100
# 12/12 - 0s - loss: 0.5667 - accuracy: 0.7592 - 37ms/epoch - 3ms/step
# Epoch 10/100
# 12/12 - 0s - loss: 0.5578 - accuracy: 0.7592 - 37ms/epoch - 3ms/step
# Epoch 11/100
# 12/12 - 0s - loss: 0.5524 - accuracy: 0.7592 - 30ms/epoch - 2ms/step
# Epoch 12/100
# 12/12 - 0s - loss: 0.5465 - accuracy: 0.7592 - 30ms/epoch - 3ms/step
# Epoch 13/100
# 12/12 - 0s - loss: 0.5421 - accuracy: 0.7592 - 34ms/epoch - 3ms/step
# Epoch 14/100
# 12/12 - 0s - loss: 0.5377 - accuracy: 0.7592 - 34ms/epoch - 3ms/step
# Epoch 15/100
# 12/12 - 0s - loss: 0.5339 - accuracy: 0.7644 - 32ms/epoch - 3ms/step
# Epoch 16/100
# 12/12 - 0s - loss: 0.5305 - accuracy: 0.7644 - 31ms/epoch - 3ms/step
# Epoch 17/100
# 12/12 - 0s - loss: 0.5270 - accuracy: 0.7644 - 25ms/epoch - 2ms/step
# Epoch 18/100
# 12/12 - 0s - loss: 0.5241 - accuracy: 0.7644 - 25ms/epoch - 2ms/step
# Epoch 19/100
# 12/12 - 0s - loss: 0.5208 - accuracy: 0.7644 - 29ms/epoch - 2ms/step
# Epoch 20/100
# 12/12 - 0s - loss: 0.5178 - accuracy: 0.7644 - 29ms/epoch - 2ms/step
# Epoch 21/100
# 12/12 - 0s - loss: 0.5147 - accuracy: 0.7644 - 34ms/epoch - 3ms/step
# Epoch 22/100
# 12/12 - 0s - loss: 0.5120 - accuracy: 0.7644 - 35ms/epoch - 3ms/step
# Epoch 23/100
# 12/12 - 0s - loss: 0.5095 - accuracy: 0.7644 - 27ms/epoch - 2ms/step
# Epoch 24/100
# 12/12 - 0s - loss: 0.5064 - accuracy: 0.7644 - 24ms/epoch - 2ms/step
# Epoch 25/100
# 12/12 - 0s - loss: 0.5037 - accuracy: 0.7644 - 24ms/epoch - 2ms/step
# Epoch 26/100
# 12/12 - 0s - loss: 0.5013 - accuracy: 0.7644 - 32ms/epoch - 3ms/step
# Epoch 27/100
# 12/12 - 0s - loss: 0.4981 - accuracy: 0.7644 - 26ms/epoch - 2ms/step
# Epoch 28/100
# 12/12 - 0s - loss: 0.4956 - accuracy: 0.7696 - 24ms/epoch - 2ms/step
# Epoch 29/100
# 12/12 - 0s - loss: 0.4930 - accuracy: 0.7749 - 28ms/epoch - 2ms/step
# Epoch 30/100
# 12/12 - 0s - loss: 0.4901 - accuracy: 0.7749 - 29ms/epoch - 2ms/step
# Epoch 31/100
# 12/12 - 0s - loss: 0.4876 - accuracy: 0.7801 - 27ms/epoch - 2ms/step
# Epoch 32/100
# 12/12 - 0s - loss: 0.4844 - accuracy: 0.7801 - 27ms/epoch - 2ms/step
# Epoch 33/100
# 12/12 - 0s - loss: 0.4821 - accuracy: 0.7853 - 30ms/epoch - 3ms/step
# Epoch 34/100
# 12/12 - 0s - loss: 0.4790 - accuracy: 0.7853 - 30ms/epoch - 3ms/step
# Epoch 35/100
# 12/12 - 0s - loss: 0.4765 - accuracy: 0.7801 - 21ms/epoch - 2ms/step
# Epoch 36/100
# 12/12 - 0s - loss: 0.4741 - accuracy: 0.7801 - 23ms/epoch - 2ms/step
# Epoch 37/100
# 12/12 - 0s - loss: 0.4719 - accuracy: 0.7801 - 36ms/epoch - 3ms/step
# Epoch 38/100
# 12/12 - 0s - loss: 0.4698 - accuracy: 0.7853 - 31ms/epoch - 3ms/step
# Epoch 39/100
# 12/12 - 0s - loss: 0.4671 - accuracy: 0.7853 - 22ms/epoch - 2ms/step
# Epoch 40/100
# 12/12 - 0s - loss: 0.4648 - accuracy: 0.7853 - 27ms/epoch - 2ms/step
# Epoch 41/100
# 12/12 - 0s - loss: 0.4625 - accuracy: 0.7853 - 62ms/epoch - 5ms/step
# Epoch 42/100
# 12/12 - 0s - loss: 0.4599 - accuracy: 0.7906 - 34ms/epoch - 3ms/step
# Epoch 43/100
# 12/12 - 0s - loss: 0.4577 - accuracy: 0.7958 - 21ms/epoch - 2ms/step
# Epoch 44/100
# 12/12 - 0s - loss: 0.4558 - accuracy: 0.7958 - 19ms/epoch - 2ms/step
# Epoch 45/100
# 12/12 - 0s - loss: 0.4537 - accuracy: 0.7958 - 20ms/epoch - 2ms/step
# Epoch 46/100
# 12/12 - 0s - loss: 0.4514 - accuracy: 0.7958 - 22ms/epoch - 2ms/step
# Epoch 47/100
# 12/12 - 0s - loss: 0.4494 - accuracy: 0.7958 - 30ms/epoch - 3ms/step
# Epoch 48/100
# 12/12 - 0s - loss: 0.4471 - accuracy: 0.7958 - 29ms/epoch - 2ms/step
# Epoch 49/100
# 12/12 - 0s - loss: 0.4451 - accuracy: 0.7958 - 32ms/epoch - 3ms/step
# Epoch 50/100
# 12/12 - 0s - loss: 0.4435 - accuracy: 0.7958 - 29ms/epoch - 2ms/step
# Epoch 51/100
# 12/12 - 0s - loss: 0.4417 - accuracy: 0.8063 - 28ms/epoch - 2ms/step
# Epoch 52/100
# 12/12 - 0s - loss: 0.4394 - accuracy: 0.8063 - 21ms/epoch - 2ms/step
# Epoch 53/100
# 12/12 - 0s - loss: 0.4381 - accuracy: 0.8063 - 27ms/epoch - 2ms/step
# Epoch 54/100
# 12/12 - 0s - loss: 0.4354 - accuracy: 0.8063 - 23ms/epoch - 2ms/step
# Epoch 55/100
# 12/12 - 0s - loss: 0.4340 - accuracy: 0.8063 - 21ms/epoch - 2ms/step
# Epoch 56/100
# 12/12 - 0s - loss: 0.4320 - accuracy: 0.8063 - 20ms/epoch - 2ms/step
# Epoch 57/100
# 12/12 - 0s - loss: 0.4301 - accuracy: 0.8063 - 23ms/epoch - 2ms/step
# Epoch 58/100
# 12/12 - 0s - loss: 0.4284 - accuracy: 0.8063 - 20ms/epoch - 2ms/step
# Epoch 59/100
# 12/12 - 0s - loss: 0.4261 - accuracy: 0.8115 - 20ms/epoch - 2ms/step
# Epoch 60/100
# 12/12 - 0s - loss: 0.4250 - accuracy: 0.8115 - 24ms/epoch - 2ms/step
# Epoch 61/100
# 12/12 - 0s - loss: 0.4226 - accuracy: 0.8168 - 59ms/epoch - 5ms/step
# Epoch 62/100
# 12/12 - 0s - loss: 0.4210 - accuracy: 0.8168 - 25ms/epoch - 2ms/step
# Epoch 63/100
# 12/12 - 0s - loss: 0.4192 - accuracy: 0.8168 - 19ms/epoch - 2ms/step
# Epoch 64/100
# 12/12 - 0s - loss: 0.4174 - accuracy: 0.8115 - 18ms/epoch - 1ms/step
# Epoch 65/100
# 12/12 - 0s - loss: 0.4155 - accuracy: 0.8168 - 21ms/epoch - 2ms/step
# Epoch 66/100
# 12/12 - 0s - loss: 0.4135 - accuracy: 0.8168 - 26ms/epoch - 2ms/step
# Epoch 67/100
# 12/12 - 0s - loss: 0.4123 - accuracy: 0.8220 - 31ms/epoch - 3ms/step
# Epoch 68/100
# 12/12 - 0s - loss: 0.4102 - accuracy: 0.8220 - 32ms/epoch - 3ms/step
# Epoch 69/100
# 12/12 - 0s - loss: 0.4086 - accuracy: 0.8272 - 31ms/epoch - 3ms/step
# Epoch 70/100
# 12/12 - 0s - loss: 0.4071 - accuracy: 0.8220 - 32ms/epoch - 3ms/step
# Epoch 71/100
# 12/12 - 0s - loss: 0.4049 - accuracy: 0.8220 - 32ms/epoch - 3ms/step
# Epoch 72/100
# 12/12 - 0s - loss: 0.4037 - accuracy: 0.8272 - 34ms/epoch - 3ms/step
# Epoch 73/100
# 12/12 - 0s - loss: 0.4016 - accuracy: 0.8272 - 29ms/epoch - 2ms/step
# Epoch 74/100
# 12/12 - 0s - loss: 0.4004 - accuracy: 0.8220 - 20ms/epoch - 2ms/step
# Epoch 75/100
# 12/12 - 0s - loss: 0.3983 - accuracy: 0.8220 - 29ms/epoch - 2ms/step
# Epoch 76/100
# 12/12 - 0s - loss: 0.3966 - accuracy: 0.8272 - 27ms/epoch - 2ms/step
# Epoch 77/100
# 12/12 - 0s - loss: 0.3950 - accuracy: 0.8325 - 18ms/epoch - 2ms/step
# Epoch 78/100
# 12/12 - 0s - loss: 0.3935 - accuracy: 0.8325 - 21ms/epoch - 2ms/step
# Epoch 79/100
# 12/12 - 0s - loss: 0.3920 - accuracy: 0.8325 - 22ms/epoch - 2ms/step
# Epoch 80/100
# 12/12 - 0s - loss: 0.3910 - accuracy: 0.8325 - 17ms/epoch - 1ms/step
# Epoch 81/100
# 12/12 - 0s - loss: 0.3893 - accuracy: 0.8377 - 27ms/epoch - 2ms/step
# Epoch 82/100
# 12/12 - 0s - loss: 0.3871 - accuracy: 0.8325 - 19ms/epoch - 2ms/step
# Epoch 83/100
# 12/12 - 0s - loss: 0.3857 - accuracy: 0.8377 - 21ms/epoch - 2ms/step
# Epoch 84/100
# 12/12 - 0s - loss: 0.3846 - accuracy: 0.8377 - 17ms/epoch - 1ms/step
# Epoch 85/100
# 12/12 - 0s - loss: 0.3830 - accuracy: 0.8377 - 22ms/epoch - 2ms/step
# Epoch 86/100
# 12/12 - 0s - loss: 0.3816 - accuracy: 0.8377 - 19ms/epoch - 2ms/step
# Epoch 87/100
# 12/12 - 0s - loss: 0.3801 - accuracy: 0.8377 - 20ms/epoch - 2ms/step
# Epoch 88/100
# 12/12 - 0s - loss: 0.3786 - accuracy: 0.8377 - 19ms/epoch - 2ms/step
# Epoch 89/100
# 12/12 - 0s - loss: 0.3769 - accuracy: 0.8377 - 31ms/epoch - 3ms/step
# Epoch 90/100
# 12/12 - 0s - loss: 0.3758 - accuracy: 0.8272 - 29ms/epoch - 2ms/step
# Epoch 91/100
# 12/12 - 0s - loss: 0.3742 - accuracy: 0.8429 - 28ms/epoch - 2ms/step
# Epoch 92/100
# 12/12 - 0s - loss: 0.3729 - accuracy: 0.8377 - 32ms/epoch - 3ms/step
# Epoch 93/100
# 12/12 - 0s - loss: 0.3713 - accuracy: 0.8429 - 27ms/epoch - 2ms/step
# Epoch 94/100
# 12/12 - 0s - loss: 0.3702 - accuracy: 0.8429 - 27ms/epoch - 2ms/step
# Epoch 95/100
# 12/12 - 0s - loss: 0.3686 - accuracy: 0.8429 - 27ms/epoch - 2ms/step
# Epoch 96/100
# 12/12 - 0s - loss: 0.3676 - accuracy: 0.8482 - 28ms/epoch - 2ms/step
# Epoch 97/100
# 12/12 - 0s - loss: 0.3664 - accuracy: 0.8482 - 23ms/epoch - 2ms/step
# Epoch 98/100
# 12/12 - 0s - loss: 0.3653 - accuracy: 0.8482 - 28ms/epoch - 2ms/step
# Epoch 99/100
# 12/12 - 0s - loss: 0.3632 - accuracy: 0.8482 - 25ms/epoch - 2ms/step
# Epoch 100/100
# 12/12 - 0s - loss: 0.3620 - accuracy: 0.8482 - 26ms/epoch - 2ms/step
# Accuracy: 71.58
